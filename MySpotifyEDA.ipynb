# %%
def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        return features[0]
    except:
        return None

# %%
def post_auth_token() -> dict:
    return requests.post(AUTH_URL, {
        'grant_type': 'client_credentials',
        'client_id': CLIENT_ID,
        'client_secret': CLIENT_SECRET,
    }).json()

# %%
token_credentials = post_auth_token()
access_tkn = token_credentials['access_token']

# %%
headers_saved = get_headers(access_tkn)
headers_top = get_headers(access_tkn)

# %% [markdown]
# Run the code from here ⬇️

# %%
# %load_ext dotenv

# %%
# %dotenv

# %%
import pandas as pd
import os
import numpy as np
import requests
import spotipy
from itertools import chain

# %%
USERNAME = os.environ.get('USERNAME')
CLIENT_ID =os.environ.get('CLIENT_ID')
CLIENT_SECRET = os.environ.get('CLIENT_SECRET')
REDIRECT_URI = os.environ.get('REDIRECT_URI')

AUTH_URL = 'https://accounts.spotify.com/api/token'
SCOPE_READ = 'user-library-read'
SCOPE_TOP = 'user-top-read'
BASE_URL = 'https://api.spotify.com/v1/'

# %%
def get_token_scope(scope:str) -> str:
    return spotipy.util.prompt_for_user_token(username=USERNAME,
                                           scope=scope,
                                           client_id=CLIENT_ID,
                                           client_secret=CLIENT_SECRET,
                                           redirect_uri=REDIRECT_URI
                                           )

# %%
def get_headers(token) -> dict:
    return {
        'Accept': 'application/json',
        'Content-Type': 'application/json',
        'Authorization': 'Bearer {token}'.format(token=token),
        }

# %%
def get_request(url:str, headers: dict, params: dict) -> dict:
    try:
        response = requests.get(url, 
                    headers = headers, params = params)
        json = response.json()
        first_result = json['items']
        return first_result
    except:
        return None

# %%
token_saved = get_token_scope(SCOPE_READ)
token_top = get_token_scope(SCOPE_TOP)

# %%
headers_saved = get_headers(token_saved)
headers_top = get_headers(token_top)

# %%
saved_tracks_from_lib = get_request(BASE_URL+f'me/tracks', headers_saved, params = {'market': 'BR'})

# %%
top_tracks = get_request(BASE_URL+f'me/top/tracks', headers_top, params = {'time_range': 'medium_term', 'limit': '50'})

# %%
top_tracks_long =  get_request(BASE_URL+f'me/top/tracks', headers_top, params = {'time_range': 'long_term', 'limit':'50'})

# %%
top_artists = get_request(BASE_URL+f'me/top/artists', headers_top, params = {'time_range': 'medium_term', 'limit': '50'})

# %%
top_artists_long = get_request(BASE_URL+f'me/top/artists', headers_top, params = {'time_range': 'long_term', 'limit': '50'})

# %% [markdown]
# Every artist is placed as one element in the list returned. This element is a dictionary, and some of the keys are:
# - genres
# - images
# - popularity
# - name
# - followers
# - uri

# %%
def create_df_artists(names: list, genres: list, popularities: list, followers: list, columns_artist: list) -> pd.DataFrame:
    
    selected_data = {}

    selected_data[columns_artist[0]] = names
    selected_data[columns_artist[1]] = genres
    selected_data[columns_artist[2]] = popularities
    selected_data[columns_artist[3]] = followers
    
    return pd.DataFrame.from_dict(selected_data)

# %%
def get_attributes_from_artists(data: list):
    followers = []
    genres = []
    name = []
    popularity = []
    
    for index in range(len(data)):
        followers.append(data[index]['followers']['total'])
        genres.append(data[index]['genres'])
        name.append(data[index]['name'])
        popularity.append(data[index]['popularity'])
    
    return followers, genres, name, popularity

# %%
columns_artist = ['name', 'genres', 'popularity', 'followers']

# %%
columns_artist = ['name', 'genres', 'popularity', 'followers']

# %%
followers_medium, genres_medium, names_medium, popularities_medium = get_attributes_from_artists(top_artists)

# %%
top_artists_medium = create_df_artists(names_medium, genres_medium, popularities_medium, followers_medium, columns_artist)
top_artists_medium
# Out:
#                          name  \
# 0                RÜFÜS DU SOL
# 1                       JAY-Z
# 2            Paul Kalkbrenner
# 3                     J. Cole
# 4                    Klanglos
# 5                  Kanye West
# 6               Jan Blomqvist
# 7                 Jorja Smith
# 8                       Drake
# 9               Natti Natasha
# 10           Armin van Buuren
# 11                   Monolink
# 12                    Rihanna
# 13                     Avicii
# 14               Nora En Pure
# 15           Lost Frequencies
# 16              Teyana Taylor
# 17              Amy Winehouse
# 18                The Carters
# 19               Jessie Reyez
# 20         Tyler, The Creator
# 21              Martin Garrix
# 22             Olivia Rodrigo
# 23                  Tinlicker
# 24                    Beyoncé
# 25                      Aminé
# 26              Isaiah Rashad
# 27                 Elderbrook
# 28                  Lil Nas X
# 29        Lous and The Yakuza
# 30                Frank Ocean
# 31                Joris Voorn
# 32  Dimitri Vegas & Like Mike
# 33                  Baby Keem
# 34               Aya Nakamura
# 35                       Xamã
# 36                       Alok
# 37                  DJ Khaled
# 38                 Bebe Rexha
# 39                        BIA
# 40                      KALEO
# 41               Milky Chance
# 42             Oliver Heldens
# 43                        EDX
# 44                OneRepublic
# 45                   Afrojack
# 46                      DVBBS
# 47                      HI-LO
# 48           Childish Gambino
# 49                    Stromae
#
#                                                genres  popularity  followers
# 0               [australian electropop, indietronica]          73     837002
# 1                  [east coast hip hop, hip hop, rap]          86    6614328
# 2   [electronica, german techno, leipzig electroni...          66     972682
# 3   [conscious hip hop, hip hop, north carolina hi...          89   14664563
# 4                                       [dark techno]          47      40016
# 5                                  [chicago rap, rap]          96   15322299
# 6      [deep euro house, electronica, minimal techno]          58     159201
# 7                     [pop, r&b, uk contemporary r&b]          76    2361293
# 8   [canadian hip hop, canadian pop, hip hop, rap,...         100   57789722
# 9   [latin, latin pop, rap latina, reggaeton, trap...          81    6662127
# 10  [dutch trance, edm, pop dance, progressive hou...          77    3956616
# 11                                      [livetronica]          64     249507
# 12  [barbadian pop, dance pop, pop, pop rap, urban...          90   45231105
# 13                   [dance pop, edm, pop, pop dance]          84   20701698
# 14  [deep house, electra, house, progressive house...          66     289354
# 15  [belgian edm, edm, pop, pop dance, tropical ho...          80    2254911
# 16  [alternative r&b, dance pop, hip pop, neo soul...          65    1242845
# 17                           [british soul, neo soul]          77    7444559
# 18                     [pop, r&b, urban contemporary]          59    1219237
# 19  [canadian contemporary r&b, canadian pop, danc...          72    1004025
# 20                                     [hip hop, rap]          86    7108929
# 21  [dance pop, dutch edm, edm, pop, pop dance, pr...          81   15125088
# 22                                              [pop]          92    8954085
# 23                                [progressive house]          71      84428
# 24                              [dance pop, pop, r&b]          85   29079862
# 25  [hip hop, pop, portland hip hop, rap, undergro...          73    1648751
# 26  [hip hop, rap, tennessee hip hop, underground ...          74     998249
# 27                 [house, pop dance, tropical house]          72     241982
# 28                              [lgbtq+ hip hop, pop]          94    6800800
# 29                                      [belgian pop]          57     145537
# 30  [alternative r&b, hip hop, lgbtq+ hip hop, neo...          84    8332188
# 31  [dutch tech house, electronica, microhouse, mi...          55     127062
# 32  [belgian dance, belgian edm, big room, dance p...          75    3112469
# 33                               [hip hop, rap, trap]          83     481144
# 34                              [basshall, francoton]          75    3103095
# 35  [brazilian hip hop, funk carioca, trap brasile...          76    1068942
# 36          [electro house, pop nacional, slap house]          82   10610053
# 37  [hip hop, miami hip hop, pop, pop rap, rap, so...          80    6478072
# 38                    [dance pop, pop, post-teen pop]          81    6720345
# 39         [escape room, r&b, rap latina, trap queen]          72     191348
# 40  [icelandic indie, icelandic rock, modern alter...          72    1333153
# 41                                       [german pop]          75    1543423
# 42  [dance pop, edm, electro house, future house, ...          73     927601
# 43  [deep groove house, deep house, deep tropical ...          62     197162
# 44  [dance pop, neo mellow, piano rock, pop, pop r...          84   12500064
# 45  [big room, dance pop, dutch house, edm, electr...          77    3735971
# 46  [canadian electronic, dance pop, edm, electro ...          69     934412
# 47     [edm, electro house, house, progressive house]          54      76240
# 48               [atl hip hop, hip hop, pop rap, rap]          79    8339557
# 49                             [belgian pop, g-house]          73    1879981

# %%
followers_long, genres_long, names_long, popularities_long = get_attributes_from_artist(top_artists_long)

# %%
data_top_artists_long = create_df_artists(names_long, genres_long, popularities_long, followers_long, columns_artist)
data_top_artists_long
# Out:
#                          name  \
# 0            Lost Frequencies
# 1                  Kanye West
# 2                RÜFÜS DU SOL
# 3                Milky Chance
# 4                Nora En Pure
# 5                        Kygo
# 6                  Rudimental
# 7   Dimitri Vegas & Like Mike
# 8                    Labrinth
# 9                     Rihanna
# 10              Billie Eilish
# 11              Martin Garrix
# 12                      Lagum
# 13           Armin van Buuren
# 14                 Ed Sheeran
# 15              Amy Winehouse
# 16                Jorja Smith
# 17               Robin Schulz
# 18                   Dua Lipa
# 19         Tyler, The Creator
# 20                      JAY-Z
# 21                    ROSALÍA
# 22                    Beyoncé
# 23                       T.I.
# 24                       KVSH
# 25                      Drake
# 26                       Xamã
# 27                     Avicii
# 28             Oliver Heldens
# 29                  Sam Feldt
# 30                 Steve Aoki
# 31                Major Lazer
# 32           Paul Kalkbrenner
# 33            Vintage Culture
# 34               David Guetta
# 35                       Alok
# 36                   J Balvin
# 37                      Silva
# 38                    J. Cole
# 39                   Klanglos
# 40                 Khruangbin
# 41                    Emicida
# 42                        Sia
# 43       A Tribe Called Quest
# 44                     Khalid
# 45              Jan Blomqvist
# 46                  Sean Paul
# 47                        EDX
# 48                     Tiësto
# 49                      DVBBS
#
#                                                genres  popularity  followers
# 0   [belgian edm, edm, pop, pop dance, tropical ho...          80    2254911
# 1                                  [chicago rap, rap]          96   15322299
# 2               [australian electropop, indietronica]          73     837002
# 3                                        [german pop]          75    1543423
# 4   [deep house, electra, house, progressive house...          66     289354
# 5               [edm, pop, pop dance, tropical house]          84    7725664
# 6   [dance pop, edm, house, pop, pop dance, tropic...          74    1297757
# 7   [belgian dance, belgian edm, big room, dance p...          75    3112469
# 8                              [indie poptimism, pop]          80    1728362
# 9   [barbadian pop, dance pop, pop, pop rap, urban...          90   45231105
# 10                                  [electropop, pop]          93   50188921
# 11  [dance pop, dutch edm, edm, pop, pop dance, pr...          81   15125088
# 12  [belo horizonte indie, brazilian edm, funk car...          68     683252
# 13  [dutch trance, edm, pop dance, progressive hou...          77    3956616
# 14                                      [pop, uk pop]          94   86086399
# 15                           [british soul, neo soul]          77    7444559
# 16                    [pop, r&b, uk contemporary r&b]          76    2361293
# 17  [dance pop, deep euro house, deep house, edm, ...          81    2821681
# 18                           [dance pop, pop, uk pop]          93   28789072
# 19                                     [hip hop, rap]          86    7108929
# 20                 [east coast hip hop, hip hop, rap]          86    6614328
# 21                                   [r&b en espanol]          80    4842330
# 22                              [dance pop, pop, r&b]          85   29079862
# 23  [atl hip hop, dance pop, dirty south rap, gang...          77    3906182
# 24                 [brazilian edm, trance brasileiro]          69     304839
# 25  [canadian hip hop, canadian pop, hip hop, rap,...         100   57789722
# 26  [brazilian hip hop, funk carioca, trap brasile...          76    1068942
# 27                   [dance pop, edm, pop, pop dance]          84   20701698
# 28  [dance pop, edm, electro house, future house, ...          73     927601
# 29  [dance pop, edm, electro house, pop, pop dance...          77     653285
# 30  [dance pop, edm, electro house, pop, pop dance...          77    3599694
# 31  [dance pop, edm, electro house, moombahton, po...          79    6243346
# 32  [electronica, german techno, leipzig electroni...          66     972682
# 33                                    [brazilian edm]          77    1547553
# 34  [big room, dance pop, edm, pop, pop dance, pop...          90   23262313
# 35          [electro house, pop nacional, slap house]          82   10610053
# 36  [latin, reggaeton, reggaeton colombiano, trap ...          95   30171487
# 37                  [nova mpb, pop lgbtq+ brasileira]          65     298348
# 38  [conscious hip hop, hip hop, north carolina hi...          89   14664563
# 39                                      [dark techno]          47      40016
# 40                                  [neo-psychedelic]          71     986566
# 41  [afrofuturismo brasileiro, brazilian hip hop, ...          67    1727353
# 42            [australian dance, australian pop, pop]          87   21110369
# 43  [alternative hip hop, conscious hip hop, east ...          69    1540528
# 44                                     [pop, pop r&b]          89   14419657
# 45     [deep euro house, electronica, minimal techno]          58     159201
# 46               [dance pop, dancehall, pop, pop rap]          82    3618481
# 47  [deep groove house, deep house, deep tropical ...          62     197162
# 48  [big room, brostep, dance pop, dutch edm, edm,...          85    5934598
# 49  [canadian electronic, dance pop, edm, electro ...          69     934412

# %% [markdown]
# Every track is placed as one element in the list returned. This element is a dictionary, and some of the keys are:
# - available markets
# - duration_ms
# - explicit
# - album
#     - name
#     - release date
#     - total tracks
#     - artists
#         - name
# - artist
#     - name
# - name
# - is_local
# - popularity
# - track_number

# %%
columns_tracks = ['track_uri', 'track_name', 'duration_ms', 'explicit', 'artist_name', 'popularity', 
                 'album_name', 'album_release_date', 'album_total_tracks', 'album_track_number', 'available_markets']

# %%
def get_attributes_from_tracks(data: list):
    track_uri = []
    track_name = []
    duration = []
    explicit = []
    artist_name = []
    popularity = []
    album_name = []
    album_release_date = []
    album_total_tracks = []
    album_track_number = []
    available_markets = []
    
    for index in range(len(data)):
        track_uri.append(data[index]['uri'])
        track_name.append(data[index]['name'])
        duration.append(data[index]['duration_ms'])
        explicit.append(data[index]['explicit'])
        artist_name.append([k['name'] for k in list(chain(data[index]['artists']))])
        popularity.append(data[index]['popularity'])
        album_name.append(data[index]['album']['name'])
        album_release_date.append(data[index]['album']['release_date'])
        album_total_tracks.append(data[index]['album']['total_tracks'])
        album_track_number.append(data[index]['track_number'])
        available_markets.append(data[index]['available_markets'])
    
    return track_uri, track_name, duration, explicit, artist_name, popularity, album_name, album_release_date, album_total_tracks, album_track_number, available_markets

# %%
def create_df_tracks(track_uri: list, track_name: list, duration: list, explicit: list, artist_name: list,
                    popularity: list, album_name: list, album_release_date: list, album_total_tracks:list, 
                    album_track_number: list, available_markets:list) -> pd.DataFrame:
    
    selected_data = {}
    
    selected_data[columns_tracks[0]] = track_uri
    selected_data[columns_tracks[1]] = track_name
    selected_data[columns_tracks[2]] = duration
    selected_data[columns_tracks[3]] = explicit
    selected_data[columns_tracks[4]] = artist_name
    selected_data[columns_tracks[5]] = popularity
    selected_data[columns_tracks[6]] = album_name
    selected_data[columns_tracks[7]] = album_release_date
    selected_data[columns_tracks[8]] = album_total_tracks
    selected_data[columns_tracks[9]] = album_track_number
    selected_data[columns_tracks[10]] = available_markets
    

    return pd.DataFrame.from_dict(selected_data)

# %%
track_uri, track_name, duration, explicit, artist_name, popularity, album_name, album_release_date, album_total_tracks, album_track_number, available_markets = get_attributes_from_tracks(top_tracks_long)

# %%
data_top_tracks_long = create_df_tracks(track_uri, track_name, duration, explicit, artist_name, popularity, album_name, album_release_date, album_total_tracks, album_track_number, available_markets)
data_top_tracks_long
# Out:
#                                track_uri  \
# 0   spotify:track:19a3JfW8BQwqHWUMbcqSx8
# 1   spotify:track:7M0fsXo6rpXOKkveYooBob
# 2   spotify:track:4WIpEgkpmeVPTBAO4pm5zy
# 3   spotify:track:0Hvvs3VDBQzJ6ksSLA7l4G
# 4   spotify:track:2fZW7ByWe46rGih0FtP2XK
# 5   spotify:track:7zcmIz44ipSUMprZKvEeRO
# 6   spotify:track:695kvY0b7RypIKs9uiRKp5
# 7   spotify:track:0elXIl26ZrovBULLTrEGK6
# 8   spotify:track:4f8Mh5wuWHOsfXtzjrJB3t
# 9   spotify:track:42KxOIhF6TIiQWb7hbA8I8
# 10  spotify:track:2qG5sZ7Si6sdK74qLxedYM
# 11  spotify:track:20ZP3Om9DvDazXrNUC7WM2
# 12  spotify:track:7Feaw9WAEREY0DUOSXJLOM
# 13  spotify:track:2XIc1pqjXV3Cr2BQUGNBck
# 14  spotify:track:6kPJZM97LwdG9QIsT7khp6
# 15  spotify:track:2bbfiUnH4CATlekDS1dxNr
# 16  spotify:track:2gZUPNdnz5Y45eiGxpHGSc
# 17  spotify:track:0uyhkR7ihEbNf12EhtHOhl
# 18  spotify:track:6Diq6oBnDVzsrNcRllXRbM
# 19  spotify:track:74tLlkN3rgVzRqQJgPfink
# 20  spotify:track:1PS1QMdUqOal0ai3Gt7sDQ
# 21  spotify:track:0wXuerDYiBnERgIpbb3JBR
# 22  spotify:track:6722sffG6lcJXkZOzwd1Ue
# 23  spotify:track:3jlbL2OTD5YmIunYzgQTAN
# 24  spotify:track:1Bx0zEdVjkFlV27iKaePug
# 25  spotify:track:0U6bQIAh6MCGo1xjbIIx2S
# 26  spotify:track:76m2MiAKQvoHsgvwRDPXx5
# 27  spotify:track:4ywzpncx1NBWVt47L4VxLj
# 28  spotify:track:6potEImiklXkwD9qFzpu15
# 29  spotify:track:7nDFTHHwfe32a8qdp9XqPy
# 30  spotify:track:7IfOWyh4jTfkcGVrXKVNq0
# 31  spotify:track:7BlBVFwvbWvcwNcUarQmjk
# 32  spotify:track:0AqMAXSzkIRMV0alAddJK8
# 33  spotify:track:5dKesZwp6deuhEeW8F1UEi
# 34  spotify:track:6zWIAnsWUkqLHh98QCvaY6
# 35  spotify:track:3fLqmaO4vvZpFZSZy52VMp
# 36  spotify:track:0dcuGoAIPAT7OrP5CGSVBA
# 37  spotify:track:7lPN2DXiMsVn7XUKtOW1CS
# 38  spotify:track:4ZHqll0Bhc1nr3hB4Eg7rg
# 39  spotify:track:2SFfTNh0UIhNQQDoUBEi3S
# 40  spotify:track:0AtP8EkGPn6SwxKDaUuXec
# 41  spotify:track:2ksOAxtIxY8yElEWw8RhgK
# 42  spotify:track:51RN0kzWd7xeR4th5HsEtW
# 43  spotify:track:6MdqqkQ8sSC0WB4i8PyRuQ
# 44  spotify:track:5CLGzJsGqhCEECcpnFQA8x
# 45  spotify:track:2cytBOLpwFRX7J9URCrFIe
# 46  spotify:track:25ZEYUgCJyf3gRxkqYbkIc
# 47  spotify:track:37eGbhE1xVFSvcKkqGb6i1
# 48  spotify:track:43zdsphuZLzwA9k4DJhU0I
# 49  spotify:track:73JHauWZNH0eIl77GHT1zn
#
#                                            track_name  duration_ms  explicit  \
# 0                                              Famous       196040      True
# 1                                             Goodbye       256786     False
# 2                                              Clouds       257306     False
# 3                                Demanding Excellence       210837     False
# 4                     Nothing Left (feat. Will Heard)       236682     False
# 5                                        Free My Mind       160645     False
# 6   Toast to Our Differences (feat. Shungudzo, Pro...       254773     False
# 7                     Habits of My Heart - EP Version       210639     False
# 8                                             I THINK       212013      True
# 9                                 Body Talk (Mamooth)       207103     False
# 10                                         Con Altura       161626     False
# 11  These Days (feat. Jess Glynne, Macklemore & Da...       211760     False
# 12  Summer Days (feat. Macklemore & Patrick Stump ...       163804      True
# 13                                 LA NOCHE DE ANOCHE       203200     False
# 14                           Solo (feat. Demi Lovato)       222653     False
# 15                                        I Will Find       224733     False
# 16                                              POWER       292093      True
# 17                       Here with You - Deluxe Intro       143805     False
# 18                                      Maldita de Ex       164257      True
# 19                                        Money Trees       386906      True
# 20                                        Gold Digger       207626      True
# 21                                            Redbone       326933      True
# 22           Let Me Live (feat. Anne-Marie & Mr Eazi)       205760     False
# 23                                     Live Your Life       338853      True
# 24                                           Man Down       267000      True
# 25                                          Instagram       184558      True
# 26                            Bem Melhor - KVSH Remix       183431     False
# 27         Here with You - Mastrovita X Mordkey Remix       195000     False
# 28                                            Forever       202536     False
# 29                                   False Confidence       223400      True
# 30                                              Aloha       218480     False
# 31                                   Yo x Ti, Tu x Mi       201040     False
# 32                                          Slow Down       211064     False
# 33                                    Hit Contagiante       137125     False
# 34     Miracles (feat. Bjørnskov) - Charlie Who Remix       247980     False
# 35                         Deixa (feat. Ana Gabriela)       176025     False
# 36                                          Leftovers       192628     False
# 37                                    drivers license       242013      True
# 38                                             Wobble       186263     False
# 39                                 Detesto Despedidas       174720     False
# 40         Remember The Name (feat. Eminem & 50 Cent)       207760      True
# 41                                              China       301714     False
# 42                                       IGOR'S THEME       200693     False
# 43                                         No Diggity       304600     False
# 44  These Days (feat. Jess Glynne, Macklemore & Da...       210772     False
# 45                                            Options       240081      True
# 46                Leave The World Behind - Radio Edit       161718     False
# 47                                    Contra La Pared       224680     False
# 48                              when the party's over       196077     False
# 49                        Million Voices - Radio Edit       194958     False
#
#                                           artist_name  popularity  \
# 0                                        [Kanye West]          73
# 1                                           [Apparat]           0
# 2                                      [Milky Chance]          45
# 3                                          [Labrinth]          46
# 4                                  [Kygo, Will Heard]          51
# 5                           [Alok, Rooftime, Dubdogz]          63
# 6         [Rudimental, Shungudzo, Protoje, Hak Baker]          40
# 7                                      [Jaymes Young]          63
# 8                                [Tyler, The Creator]          71
# 9   [Moguai, Dimitri Vegas & Like Mike, Julian Per...          34
# 10                    [ROSALÍA, J Balvin, El Guincho]          75
# 11  [Rudimental, Jess Glynne, Macklemore, Dan Caplen]          69
# 12          [Martin Garrix, Macklemore, Fall Out Boy]          75
# 13                               [Bad Bunny, ROSALÍA]          85
# 14                        [Clean Bandit, Demi Lovato]          73
# 15                        [Vintage Culture, Rooftime]          68
# 16                                       [Kanye West]          78
# 17                         [Lost Frequencies, Netsky]          14
# 18                                        [Mc Leozin]          61
# 19                         [Kendrick Lamar, Jay Rock]          70
# 20                           [Kanye West, Jamie Foxx]          78
# 21                                 [Childish Gambino]          82
# 22     [Rudimental, Major Lazer, Anne-Marie, Mr Eazi]          48
# 23                                    [T.I., Rihanna]          75
# 24                                          [Rihanna]          69
# 25  [Dimitri Vegas & Like Mike, David Guetta, Dadd...          69
# 26                                      [Lagum, KVSH]          54
# 27    [Lost Frequencies, Netsky, Mastrovita, Mordkey]          16
# 28                                         [Labrinth]          76
# 29                                       [Noah Kahan]          68
# 30                               [Møme, Merryn Jeann]          65
# 31                                   [ROSALÍA, Ozuna]          74
# 32                      [Maverick Sabre, Jorja Smith]          45
# 33  [Felipe Original, MC Kevin o Chris, Sodré, JS ...          60
# 34           [Martin Jensen, Bjørnskov, Charlie Who?]          30
# 35                              [Lagum, Ana Gabriela]          69
# 36                                     [Dennis Lloyd]          62
# 37                                   [Olivia Rodrigo]          52
# 38                                         [Flo Rida]          47
# 39                                            [Lagum]          41
# 40                      [Ed Sheeran, Eminem, 50 Cent]          68
# 41  [Anuel AA, Daddy Yankee, KAROL G, J Balvin, Oz...          76
# 42                               [Tyler, The Creator]          65
# 43                  [Blackstreet, Dr. Dre, Queen Pen]          76
# 44  [Rudimental, Jess Glynne, Macklemore, Dan Caplen]          74
# 45                                  [NSG, Tion Wayne]          60
# 46  [Axwell, Sebastian Ingrosso, Steve Angello, La...          60
# 47                              [Sean Paul, J Balvin]          69
# 48                                    [Billie Eilish]          82
# 49                                       [Otto Knows]          38
#
#                                            album_name album_release_date  \
# 0                                   The Life Of Pablo         2016-06-10
# 1                                    The Devil's Walk               2011
# 2                                    Blossom (Deluxe)         2017-03-17
# 3       Euphoria (Original Score from the HBO Series)         2019-10-04
# 4                                          Cloud Nine         2016-05-13
# 5                                        Free My Mind         2020-02-21
# 6           Toast to Our Differences (Deluxe Edition)         2019-01-25
# 7                                  Habits of My Heart         2014-09-28
# 8                                                IGOR         2019-05-17
# 9                                 Body Talk (Mammoth)         2014-07-17
# 10                                         Con Altura         2019-03-28
# 11          Toast to Our Differences (Deluxe Edition)         2019-01-25
# 12  Summer Days (feat. Macklemore & Patrick Stump ...         2019-04-25
# 13                           EL ÚLTIMO TOUR DEL MUNDO         2020-11-27
# 14                           Solo (feat. Demi Lovato)         2018-05-17
# 15                                        I Will Find         2018-09-28
# 16                  My Beautiful Dark Twisted Fantasy         2010-11-22
# 17                            Here With You (Remixes)         2017-09-29
# 18                                      Maldita de Ex         2019-06-27
# 19                             good kid, m.A.A.d city               2012
# 20                                  Late Registration         2005-08-30
# 21                                 "Awaken, My Love!"         2016-12-02
# 22          Toast to Our Differences (Deluxe Edition)         2019-01-25
# 23                                        Paper Trail         2008-09-07
# 24                                               Loud         2010-11-16
# 25                                          Instagram         2019-07-05
# 26                            Bem Melhor (KVSH Remix)         2018-10-12
# 27                            Here With You (Remixes)         2017-09-29
# 28      Euphoria (Original Score from the HBO Series)         2019-10-04
# 29                                           Busyhead         2019-06-14
# 30                                           Panorama         2016-11-25
# 31                                   Yo x Ti, Tu x Mi         2019-08-15
# 32                                          Slow Down         2019-02-07
# 33                                    Hit Contagiante         2019-07-26
# 34     Miracles (feat. Bjørnskov) [Charlie Who Remix]         2016-03-04
# 35                         Deixa (feat. Ana Gabriela)         2018-02-23
# 36                                          Leftovers         2017-01-15
# 37                                    drivers license         2021-01-08
# 38                                           My House         2015-04-07
# 39                                 Detesto Despedidas         2019-03-29
# 40                        No.6 Collaborations Project         2019-07-12
# 41                                              China         2019-07-19
# 42                                               IGOR         2019-05-17
# 43                                      Another Level         1996-09-09
# 44  These Days (feat. Jess Glynne, Macklemore & Da...         2018-01-19
# 45                                            Options         2018-11-30
# 46                             Leave The World Behind         2009-05-04
# 47                                    Contra La Pared         2019-03-14
# 48           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?         2019-03-29
# 49                               Ibiza Dance Classics         2020-06-12
#
#     album_total_tracks  album_track_number  \
# 0                   20                   4
# 1                   10                   4
# 2                   20                   5
# 3                   26                  21
# 4                   15                  12
# 5                    1                   1
# 6                   16                   1
# 7                    5                   1
# 8                   12                   3
# 9                    2                   1
# 10                   1                   1
# 11                  16                   6
# 12                   1                   1
# 13                  16                   5
# 14                   1                   1
# 15                   1                   1
# 16                  13                   3
# 17                   6                   1
# 18                   1                   1
# 19                  14                   5
# 20                  21                   4
# 21                  11                   6
# 22                  16                   2
# 23                  16                   5
# 24                  12                   7
# 25                   1                   1
# 26                   1                   1
# 27                   6                   4
# 28                  26                   4
# 29                  10                   1
# 30                  13                   8
# 31                   1                   1
# 32                   1                   1
# 33                   1                   1
# 34                   1                   1
# 35                   1                   1
# 36                   1                   1
# 37                   1                   1
# 38                   7                   4
# 39                   1                   1
# 40                  15                   8
# 41                   1                   1
# 42                  12                   1
# 43                  19                   3
# 44                   1                   1
# 45                   1                   1
# 46                   2                   1
# 47                   2                   1
# 48                  14                   7
# 49                  23                  23
#
#                                     available_markets
# 0   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 1                                                  []
# 2   [AD, AE, AR, AT, BE, BG, BH, BO, BR, CH, CL, C...
# 3   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 4   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 5                                                [BR]
# 6   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 7   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 8   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 9                                                [BR]
# 10  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 11  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 12  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 13  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 14  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 15  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 16  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 17  [AR, BO, BR, CL, CO, CR, EC, GT, HN, MX, NI, P...
# 18  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 19  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 20  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 21  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 22  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 23  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 24  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 25  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 26  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 27  [AR, BO, BR, CL, CO, CR, EC, GT, HN, MX, NI, P...
# 28  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 29  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 30  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 31  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 32  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 33  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 34  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 35  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 36  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 37                                                 []
# 38  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 39  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 40  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 41  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 42  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 43  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 44  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 45  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 46  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 47  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 48  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 49  [AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, CH, C...

# %%
track_uri, track_name, duration, explicit, artist_name, popularity, album_name, album_release_date, album_total_tracks, album_track_number, available_markets = get_attributes_from_tracks(top_tracks)

# %%
data_top_tracks_medium = create_df_tracks(track_uri, track_name, duration, explicit, artist_name, popularity, album_name, album_release_date, album_total_tracks, album_track_number, available_markets)
data_top_tracks_medium
# Out:
#                                track_uri  \
# 0   spotify:track:0wXuerDYiBnERgIpbb3JBR
# 1   spotify:track:24NPziq3dayIMKppeI94Um
# 2   spotify:track:6t90Z9XkdsHD8xMxro6KRP
# 3   spotify:track:2xUsXYIiK18wSnv2SXFGtj
# 4   spotify:track:54CipIOeFb1lZYFhHi26lo
# 5   spotify:track:5Pt83OUaK3K9C2if4C5JOk
# 6   spotify:track:6rGBks2LevDjAMo5KJq88Y
# 7   spotify:track:4L7jMAP8UcIe309yQmkdcO
# 8   spotify:track:2wi4d9kls0CWgE4RsghZyR
# 9   spotify:track:4slSrbTK1sNK4I1mDYEthf
# 10  spotify:track:0aYt10BH2QvudRK5rbnDnv
# 11  spotify:track:1m5demYkTI5BB9sTx5v13h
# 12  spotify:track:4Li2WHPkuyCdtmokzW2007
# 13  spotify:track:27NovPIUIRrOZoCHxABJwK
# 14  spotify:track:6qiPrJwiT5BHKeGPF11cTO
# 15  spotify:track:08LwMWf5Tcfsd752EPzFV0
# 16  spotify:track:7LR85XLWw2yXqKBSI5brbG
# 17  spotify:track:1D3z6HTiQsNmZxjl7F7eoG
# 18  spotify:track:1wCjlErPp61MwhSvm09lsF
# 19  spotify:track:3SIgBSv9D8Nm3CvP0o0Q9Z
# 20  spotify:track:2bLqfJjuC5syrsgDsZfGmn
# 21  spotify:track:5acSb48zFAcXTdL5Wsk8xx
# 22  spotify:track:20Tc62gPQKX6Rb7gfZuVbI
# 23  spotify:track:40uMIn2zJLAQhNXghRjBed
# 24  spotify:track:6k26nyIM60y90BuZ7XR9F8
# 25  spotify:track:6tr6I3YJnHUqKHfJXnm4jk
# 26  spotify:track:3B5yl01KF06NkYG39BdTBa
# 27  spotify:track:7xGfPbWWUc9nO8p0PiPETh
# 28  spotify:track:45OFdc22XhgVhtiFwcoDTi
# 29  spotify:track:6jG2YzhxptolDzLHTGLt7S
# 30  spotify:track:66u6ycRUqlrW9C05QJUmSo
# 31  spotify:track:7CuXB3Dr61IvDFEWfqG3sE
# 32  spotify:track:7p3dHzH2BadJI74eYNPo5o
# 33  spotify:track:5R691ipUYRDYW6ehapjoj6
# 34  spotify:track:1gtUXHPyPUEWKRSevnpPY1
# 35  spotify:track:4wuY7AFjWkbltPwugDpR4U
# 36  spotify:track:7vXoveyI4GRF6VBRPayZpo
# 37  spotify:track:0y1QJc3SJVPKJ1OvFmFqe6
# 38  spotify:track:4lvv4prfWf6bSMg54vOtWO
# 39  spotify:track:52RK8UVEDgUAgpecOpTQM3
# 40  spotify:track:08T26i7SErk6jCDTW7uUFI
# 41  spotify:track:0YUGJqp62m6c7PMp2BdT03
# 42  spotify:track:3Osd3Yf8K73aj4ySn6LrvK
# 43  spotify:track:6VLEVV3KmHCiGHrY9qlXqB
# 44  spotify:track:350l5Tkctw6RMcIdl7MlaS
# 45  spotify:track:6vjbtMGvDP74WAiwyzYzlF
# 46  spotify:track:7epRJJqKxeYCaynjkMXKya
# 47  spotify:track:7nlSk1vKt1OsVazcPZCiVj
# 48  spotify:track:4lLmG1fatRUgnRz0Ol0WUi
# 49  spotify:track:2Gjt4rUHBUH0rMKpBg0hF4
#
#                                            track_name  duration_ms  explicit  \
# 0                                             Redbone       326933      True
# 1                                          Last Night       255706     False
# 2                                       Consideration       161066      True
# 3                  Invisible - Paul Kalkbrenner Remix       457036     False
# 4                                              Claire       287579     False
# 5                                       Gotta Have It       140746      True
# 6                       No Goodbye - Extended Version       390920     False
# 7                                                Lost       234093      True
# 8                                          Rendezvous       260493     False
# 9                                   Rover (feat. DTG)       167916      True
# 10               Desert Night - Live from Joshua Tree       335360     False
# 11                                                713       193386      True
# 12                                    Ni**as In Paris       219333      True
# 13                  INDUSTRY BABY (feat. Jack Harlow)       212000      True
# 14                                             Frozen       220920     False
# 15                                  i n t e r l u d e       133021      True
# 16                                      Run This Town       267520      True
# 17            m y . l i f e (with 21 Savage & Morray)       218801      True
# 18                                          Vergessen       542769     False
# 19                                            New Day       272853      True
# 20                                      The Way I Are       179120     False
# 21                                         Lean On Me       149856     False
# 22            The Flute Song - Paul Kalkbrenner Remix       304946     False
# 23                                        Motley Crew       184213      True
# 24                                          Te Quiero       204000     False
# 25                                         All I Know       148801     False
# 26   Just For Me (with SZA) - Space Jam: A New Legacy       217394     False
# 27                    Desert Night - Jesse Rose Remix       381906     False
# 28                              COFFIN (feat. Eminem)       261773      True
# 29                        Drunk in Love (feat. Jay-Z)       323480      True
# 30                                        ave cesaria       249520     False
# 31                                               More       216699     False
# 32                                          Discovery       331875     False
# 33                                    9 5 . s o u t h       196946      True
# 34  La Mezcla (feat. Totó La Momposina) - Paul Kal...       599085     False
# 35                                               Gone       195275     False
# 36     The Prey - Gui Boratto & Vintage Culture Remix       400113     False
# 37                                     Way down We Go       213706     False
# 38                                         Existencia       278849     False
# 39                                        You Make Me       233346     False
# 40                                           Lift Off       266253      True
# 41                               Deception - Original       431228     False
# 42                              No Church In The Wild       272506      True
# 43                                               BOSS       244133      True
# 44                                              scars       266010      True
# 45                                    Noches en Miami       154813     False
# 46                                        Me Felicito       201386     False
# 47                          Only Be Me - Duskus Remix       219318     False
# 48                                     Why I Love You       201373      True
# 49                       Disco Arranhado - Funk Remix       125557     False
#
#                                     artist_name  popularity  \
# 0                            [Childish Gambino]          82
# 1                         [Keyshia Cole, Diddy]          62
# 2                                [Rihanna, SZA]          68
# 3                       [NTO, Paul Kalkbrenner]          61
# 4    [Anyma, Janus Rasmussen, Delhia De France]          50
# 5                           [JAY-Z, Kanye West]          65
# 6                            [Paul Kalkbrenner]          50
# 7                                 [Frank Ocean]          72
# 8                                [RÜFÜS DU SOL]          51
# 9                                  [S1mba, DTG]          72
# 10                               [RÜFÜS DU SOL]          45
# 11                                [The Carters]          44
# 12                          [JAY-Z, Kanye West]          81
# 13                     [Lil Nas X, Jack Harlow]          98
# 14                              [Natti Natasha]          55
# 15                                    [J. Cole]          75
# 16                 [JAY-Z, Rihanna, Kanye West]          74
# 17                 [J. Cole, 21 Savage, Morray]          81
# 18                                   [Klanglos]          47
# 19                          [JAY-Z, Kanye West]          55
# 20             [Timbaland, Keri Hilson, D.O.E.]          78
# 21                       [Cheat Codes, Tinashe]          71
# 22               [Kid Simius, Paul Kalkbrenner]          49
# 23                                [Post Malone]          85
# 24                                    [Stromae]          53
# 25                                        [EDX]          49
# 26                             [SAINt JHN, SZA]          68
# 27                               [RÜFÜS DU SOL]          42
# 28                       [Jessie Reyez, Eminem]          33
# 29                             [Beyoncé, JAY-Z]          70
# 30                                    [Stromae]          57
# 31              [Jan Blomqvist, Elena Pitoulis]          52
# 32                                   [Klanglos]          22
# 33                                    [J. Cole]          73
# 34            [Michel Cleis, Totó La Momposina]          33
# 35                                [Jorja Smith]          57
# 36     [Monolink, Gui Boratto, Vintage Culture]          55
# 37                                      [KALEO]          78
# 38   [Reinier Zonneveld, HI-LO, Oliver Heldens]          50
# 39                                     [Avicii]          65
# 40                 [JAY-Z, Kanye West, Beyoncé]          58
# 41                                   [DJ Randy]          17
# 42  [JAY-Z, Kanye West, Frank Ocean, The-Dream]          72
# 43                                [The Carters]          50
# 44                                  [Baby Keem]          68
# 45                              [Natti Natasha]          58
# 46                              [Natti Natasha]          52
# 47                            [DROELOE, Duskus]          42
# 48               [JAY-Z, Kanye West, Mr Hudson]          58
# 49                        [Malu, DJ Lucas Beat]          75
#
#                                         album_name album_release_date  \
# 0                               "Awaken, My Love!"         2016-12-02
# 1                                    Just Like You               2007
# 2                                    ANTI (Deluxe)         2016-01-28
# 3               Invisible (Paul Kalkbrenner Remix)         2021-04-14
# 4                                           Claire         2021-07-16
# 5                        Watch The Throne (Deluxe)         2011-08-08
# 6                                       No Goodbye         2019-07-26
# 7                channel ORANGE (Explicit Version)         2012-07-10
# 8              Atlas (Light / Dark Deluxe Edition)               2013
# 9                                Rover (feat. DTG)         2020-03-04
# 10                           Live from Joshua Tree         2020-03-06
# 11                              EVERYTHING IS LOVE         2018-06-18
# 12                       Watch The Throne (Deluxe)         2011-08-08
# 13               INDUSTRY BABY (feat. Jack Harlow)         2021-07-23
# 14                                      NATTIVIDAD         2021-09-24
# 15                                  The Off-Season         2021-05-14
# 16                                 The Blueprint 3         2009-09-08
# 17                                  The Off-Season         2021-05-14
# 18                                       Vergessen         2020-10-03
# 19                       Watch The Throne (Deluxe)         2011-08-08
# 20                                     Shock Value         2007-01-01
# 21                             HELLRAISERS, Part 1         2021-05-07
# 22         The Flute Song (Paul Kalkbrenner Remix)         2017-11-17
# 23                                     Motley Crew         2021-07-09
# 24                                          Cheese         2010-01-01
# 25                                      All I Know         2017-04-10
# 26           Just For Me (Space Jam: A New Legacy)         2021-06-11
# 27             Atlas (Light / Dark Deluxe Edition)               2013
# 28            BEFORE LOVE CAME TO KILL US (Deluxe)         2020-04-02
# 29                      BEYONCÉ [Platinum Edition]         2014-11-24
# 30                                   racine carrée         2013-01-01
# 31                                            More         2016-02-05
# 32                                   The Breakdown         2020-04-13
# 33                                  The Off-Season         2021-05-14
# 34     La Mezcla (feat. Totó la Momposina) [Pt. 2]         2010-01-11
# 35                                   Be Right Back         2021-05-14
# 36  The Prey (Gui Boratto & Vintage Culture Remix)         2021-04-02
# 37                                             A/B         2016-06-10
# 38                                      Existencia         2021-08-06
# 39                                            True         2013-01-01
# 40                       Watch The Throne (Deluxe)         2011-08-08
# 41                                        Pandomia         1997-01-01
# 42                       Watch The Throne (Deluxe)         2011-08-08
# 43                              EVERYTHING IS LOVE         2018-06-18
# 44                                The Melodic Blue         2021-09-10
# 45                                      NATTIVIDAD         2021-09-24
# 46                                      NATTIVIDAD         2021-09-24
# 47                       Only Be Me (Duskus Remix)         2019-03-01
# 48                       Watch The Throne (Deluxe)         2011-08-08
# 49                    Disco Arranhado (Funk Remix)         2021-01-22
#
#     album_total_tracks  album_track_number  \
# 0                   11                   6
# 1                   16                   2
# 2                   16                   1
# 3                    1                   1
# 4                    3                   1
# 5                   16                   5
# 6                    2                   2
# 7                   17                  11
# 8                   23                   5
# 9                    1                   1
# 10                   8                   4
# 11                   9                   5
# 12                  16                   3
# 13                   1                   1
# 14                  17                   1
# 15                  12                   9
# 16                  15                   4
# 17                  12                   3
# 18                   1                   1
# 19                  16                   6
# 20                  17                   4
# 21                  11                   2
# 22                   1                   1
# 23                   1                   1
# 24                  12                   2
# 25                   1                   1
# 26                   1                   1
# 27                  23                   4
# 28                  17                   4
# 29                  20                   3
# 30                  13                   4
# 31                   2                   1
# 32                  24                   1
# 33                  12                   1
# 34                   3                   1
# 35                   8                   2
# 36                   1                   1
# 37                  10                   2
# 38                   1                   1
# 39                  10                   2
# 40                  16                   2
# 41                   2                   2
# 42                  16                   1
# 43                   9                   3
# 44                  16                  11
# 45                  17                   3
# 46                  17                   9
# 47                   1                   1
# 48                  16                  12
# 49                   1                   1
#
#                                     available_markets
# 0   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 1   [AD, AR, AT, AU, BE, BG, BO, BR, CH, CL, CO, C...
# 2   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 3   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 4   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 5   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 6   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 7   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CH, C...
# 8   [AE, AR, AT, AU, BH, BO, BR, CA, CH, CL, CO, C...
# 9   [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 10  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 11  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 12  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 13  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 14  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 15  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 16  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 17  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 18  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 19  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 20  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 21  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 22  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 23  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 24  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 25  [AD, AE, AR, AU, BE, BG, BH, BO, BR, CA, CL, C...
# 26  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 27  [AE, AR, AT, BH, BO, BR, CA, CH, CL, CO, CR, C...
# 28  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 29  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 30  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 31  [AD, AE, AR, AU, BE, BG, BH, BO, BR, CA, CL, C...
# 32  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 33  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 34  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 35  [AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, CH, C...
# 36  [AR, BO, BR, CA, CL, CO, CR, DO, EC, GT, HN, M...
# 37  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 38  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 39  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 40  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 41  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 42  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 43  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 44  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 45  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 46  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 47  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 48  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 49  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
